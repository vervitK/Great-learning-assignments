# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Take-Home <br>(Day 1)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Customer Tip Data)
#
# The dataset contains information about the 244 orders served at a restaurant in the United States. Each observation includes the factors related to the order like total bill, time, the total number of people in a group, gender of the person paying for the order and so on.
#
# Attribute Information:
#
# **total_bill:** Total bill (cost of the meal), including tax, in US dollars
#
# **tip:** Tip in US dollars
#
# **sex:** Sex of person paying for the meal
#
# **smoker:** There is a smoker in a group or not
#
# **day:** Day on which the order is served
#
# **time:** Time of the order
#
# **size:** Size of the group

# %% [markdown]
# **Import the required libraries**

# %%
import numpy as np 
import pandas as pd
import scipy as sp
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the customer tip dataset and print the first five observations

# %%
df  = sns.load_dataset('tips')

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Make a list of categorical and numerical variables in the data
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Compute the average bill amount for each day
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Which gender is more generous in giving the tip?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.groupby('sex')['total_bill'].mean()
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. According to the data, were there more customers for dinner or lunch? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Based on the statistical summary, comment on the variable 'tip'
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Find the busiest day in terms of the orders
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.groupby('day')['size'].count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: size, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Is the variable 'total_bill' skewed? If yes, identify the type of skewness. Support your answer with a plot
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(df['total_bill'].skew())
sns.displot(data =df ,x = 'total_bill',kind = 'kde')
# Out:
# 1.1332130376158205

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Is the tip amount dependent on the total bill?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.corr()
# yes tip amount depends on total bill
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9.  What is the value under which 20% of the total bill would lie?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sp.percentile(df['total_bill'],20)
# Out:
# <ipython-input-28-4f226a827fd1>:1: DeprecationWarning: scipy.percentile is deprecated and will be removed in SciPy 2.0.0, use numpy.percentile instead
#   sp.percentile(df['total_bill'],20)
# 12.636

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Retrieve the orders where the bill amount is more than 2 standard deviation away from the average bill </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
df['total_bill'].std()
# Out:
# 8.902411954856856

# %%
# Out:
# 0       7.817295
# 1      89.225832
# 2       1.498316
# 3      15.163683
# 4      23.078967
#          ...
# 239    85.452597
# 240    54.672084
# 241     8.317787
# 242     3.864930
# 243     1.011921
# Name: total_bill, Length: 244, dtype: float64

# %%
#df['z_score'] =

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
df['total_bill'].std()
# Out:
# 8.902411954856856

# %%
df['z_score'] = (df['total_bill']-df['total_bill'].mean())/df['total_bill'].std()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   z_score
# 0       16.99  1.01  Female     No  Sun  Dinner     2 -0.314066
# 1       10.34  1.66    Male     No  Sun  Dinner     3 -1.061054
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.137497
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.437416
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.539635

# %%
from scipy.stats import zscore

# %%
df['ztb'] = zscore(df['total_bill'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   z_score       ztb
# 0       16.99  1.01  Female     No  Sun  Dinner     2 -0.314066 -0.314711
# 1       10.34  1.66    Male     No  Sun  Dinner     3 -1.061054 -1.063235
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.137497  0.137780
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.437416  0.438315
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.539635  0.540745

# %%
sns.distplot(df['ztb'])
# Out:
# /Users/Vervit_khandelwal/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ztb', ylabel='Density'>

# %%
g = sns.FacetGrid(df, "ztb")
g.map(sns.histplot,'total_bill')
# Out:
# /Users/Vervit_khandelwal/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: row. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-460192787b65> in <module>
#       1 g = sns.FacetGrid(df, "ztb")
# ----> 2 g.map(sns.histplot,'total_bill')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     682
#     683             # Draw the plot
# --> 684             self._facet_plot(func, ax, plot_args, kwargs)
#     685
#     686         # Finalize the annotations and layout
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     772                 plot_kwargs[key] = val
#     773             plot_args = []
# --> 774         func(*plot_args, **plot_kwargs)
#     775
#     776         # Sort out the supporting information
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1420     if p.univariate:
#    1421
# -> 1422         p.plot_univariate_histogram(
#    1423             multiple=multiple,
#    1424             element=element,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     651                 # Needed in some cases to get valid transforms.
#     652                 # Innocuous in other cases?
# --> 653                 ax.autoscale_view()
#     654
#     655                 # We will base everything on the minimum bin width
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2577             # End of definition of internal function 'handle_single_axis'.
#    2578
# -> 2579         handle_single_axis(
#    2580             scalex, self._autoscaleXon, self._shared_x_axes, 'intervalx',
#    2581             'minposx', self.xaxis, self._xmargin, x_stickies, self.set_xbound)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in handle_single_axis(scale, autoscaleon, shared_axes, interval, minpos, axis, margin, stickies, set_bound)
#    2574             if not self._tight:
#    2575                 x0, x1 = locator.view_limits(x0, x1)
# -> 2576             set_bound(x0, x1)
#    2577             # End of definition of internal function 'handle_single_axis'.
#    2578
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in set_xbound(self, lower, upper)
#    3170             upper = old_upper
#    3171
# -> 3172         self.set_xlim(sorted((lower, upper),
#    3173                              reverse=bool(self.xaxis_inverted())),
#    3174                       auto=None)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3344             for other in self._shared_x_axes.get_siblings(self):
#    3345                 if other is not self:
# -> 3346                     other.set_xlim(self.viewLim.intervalx,
#    3347                                    emit=False, auto=auto)
#    3348                     if other.figure != self.figure:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3334         self._viewLim.intervalx = (left, right)
#    3335         # Mark viewlims as no longer stale without triggering an autoscale.
# -> 3336         for ax in self._shared_x_axes.get_siblings(self):
#    3337             ax._stale_viewlim_x = False
#    3338         if auto is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in get_siblings(self, a)
#     855         self.clean()
#     856         siblings = self._mapping.get(weakref.ref(a), [weakref.ref(a)])
# --> 857         return [x() for x in siblings]
#     858
#     859
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in <listcomp>(.0)
#     855         self.clean()
#     856         siblings = self._mapping.get(weakref.ref(a), [weakref.ref(a)])
# --> 857         return [x() for x in siblings]
#     858
#     859
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(1,2,figsize=(15,8))
df['sex'].value_counts().plot(kind='bar',ax=axes[0])
df['sex'].value_counts().plot(kind='pie',ax=axes[1])
plt.show()

# %%
fig, axes = plt.subplots(1,2,figsize=(15,8))
sns.distplot(df['total_bill'],ax = axes[0])
sns.distplot(df['ztb'],ax = axes[1])
plt.show()
# Out:
# /Users/Vervit_khandelwal/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/Vervit_khandelwal/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m = MinMaxScaler()

# %%
df['mtb'] = m.fit_transform(df[['total_bill']])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   z_score       ztb  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2 -0.314066 -0.314711
# 1       10.34  1.66    Male     No  Sun  Dinner     3 -1.061054 -1.063235
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.137497  0.137780
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.437416  0.438315
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.539635  0.540745
#
#         mtb
# 0  0.291579
# 1  0.152283
# 2  0.375786
# 3  0.431713
# 4  0.450775

# %%
df['mtb'].skew()
# Out:
# 1.1332130376158203

# %%
df['mtb'].kurt()
# Out:
# 1.2184840156638836

# %%
df['total_bill'].skew()
# Out:
# 1.1332130376158205
