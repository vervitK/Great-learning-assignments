# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Take-Home <br>(Day 4)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 1. Plot a  bar chart and vertical bar chart for the following data.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
# <tr>
#     <th>Name</th>
#     <td>Sheldon</td>
#     <td>Amy</td>
#     <td>Priya</td>
#     <td>Raj</td>
# </tr>
# <tr>
#     <th>Maths</th>
#     <td>72</td>
#     <td>34</td>
#     <td>54</td>
#     <td>76</td>
# </tr>
# <tr>
#     <th>Geography</th>
#     <td>98</td>
#     <td>98</td>
#     <td>78</td>
#     <td>87</td>
#   </tr>
# </table>

# %%
df = pd.DataFrame({'Name':['Sheldon','Amy','Priya','Raj'],
    'Maths':[72,34,54,76],
                   'Geography':[98,98,78,78]})

# %%
fig, axes= plt.subplots(1,2, figsize=(8,5))
axes[0].barh(df['Name'], df['Maths'])
axes[1].barh(df['Name'], df['Geography'])
# Out:
# <BarContainer object of 4 artists>

# %%
fig, axes= plt.subplots(1,2, figsize=(8,5))
sns.barplot(df['Name'], df['Maths'], ax=axes[0])
sns.barplot(df['Name'], df['Geography'], ax=axes[1])
plt.show()
# Out:
# /Users/Vervit_khandelwal/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Vervit_khandelwal/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 2. Following is data on 10 people, information on the number of dependents on each of them and their income is given. Draw a dual-axis plot.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
# <tr>
#     <th>Person</th>
#     <td>No. of Dependents</td>
#     <td>Income</td>
# </tr>
# <tr>
#     <th>1</th>
#     <td>1</td>
#     <td>60000</td>
# </tr>
# <tr>
#     <th>2</th>
#     <td>2</td>
#     <td>52000</td>
# </tr>
# <tr>
#     <th>3</th>
#     <td>0</td>
#     <td>50000</td>
# </tr>
# <tr>
#     <th>4</th>
#     <td>3</td>
#     <td>65000</td>
# </tr>
# <tr>
#     <th>5</th>
#     <td>0</td>
#     <td>45500</td>
# </tr>
# <tr>
#     <th>6</th>
#     <td>1</td>
#     <td>43050</td>
# </tr>
# <tr>
#     <th>7</th>
#     <td>0</td>
#     <td>54300</td>
# </tr>
# <tr>
#     <th>8</th>
#     <td>0</td>
#     <td>38000</td>
# </tr>
# <tr>
#     <th>9</th>
#     <td>2</td>
#     <td>20000</td>
# </tr>
# <tr>
#     <th>10</th>
#     <td>1</td>
#     <td>47500</td>
#     </tr>
# </table>

# %%
p= [i for i in range(1,11)]
no= [1,2,0,3,0,1,0,0,2,1]
i=[60000,52000, 50000, 65000, 45500, 43050, 54300,38000, 20000, 47500]
df2= pd.DataFrame(list(zip(p,no,i)), columns=['Person', 'no of dependents', 'income'])
df2
# Out:
#    Person  no of dependents  income
# 0       1                 1   60000
# 1       2                 2   52000
# 2       3                 0   50000
# 3       4                 3   65000
# 4       5                 0   45500
# 5       6                 1   43050
# 6       7                 0   54300
# 7       8                 0   38000
# 8       9                 2   20000
# 9      10                 1   47500

# %%
fig, axes= plt.subplots(1,1, figsize=(8,3), dpi=100)
axes.plot(df2['Person'], df2['income'], color= 'g')
axes.set_ylabel('income')
axes.set_xlabel('index of person')
axes.grid('dark')
axes.legend(['income'], loc=1)

ax1= axes.twinx()
ax1.set_ylabel('no of dependents')
ax1.plot(df2['Person'], df2['no of dependents'], color= 'b')
ax1.legend(['dependents'], loc=2)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 3. Use the following data to plot a pie chart and annotate the percentage sales.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Location</th>
#   <th>Sale</th>
#   </tr>
#   <tr>
#   <td>Delhi</td>
#   <td>42500</td>
#   </tr>
#   <tr>
#   <td>Bangalore</td>
#   <td>44500</td>
#   </tr>
#   <tr>
#   <td>Chennai</td>
#   <td>48300</td>
#   </tr>
#   <tr>
#   <td>Pune</td>
#   <td>52400</td>
#   </tr>
#   <tr>
#   <td>Kolkata</td>
#   <td>61800</td>
#   </tr>
# </table>

# %%
df3 = pd.DataFrame({'Location':['Delhi','Bangalore','Chennai','Pune','Kolkata'],
                    'Sales':[42500,44500,48300,52400,61800]})
plt.pie(x= 'Sales',data= df3,labels='Location',autopct="%.1f%%")
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 4. Write a program to plot a bar plot of seven students representing their marks in Mathematics using plotly.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#         marks = [76,98,78,98,89,56,69,76]
#         students = ['Sheldon','Leonard','Raj','Howard','Amy','Penny','Bernadette']

# %%
df4 = pd.DataFrame({ 'marks' : [76,98,78,98,89,56,69,76],
                   'students' : ['Sheldon','Leonard','Raj','Howard','Amy','Penny','Bernadette','Ajay']})
fig = plt.figure()
plt.bar(x='students',data=df4,height='marks')
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 5. Import the flights data set and plot a line plot for the variable 'passengers'.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df5 = sns.load_dataset('flights')
sns.lineplot(y = 'passengers',x='month',data=df5)
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 6. Import the iris data set and plot a heatmap of the correlation between its numeric variables.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df6 =sns.load_dataset('Iris')
x =  df6.corr()
sns.heatmap(x,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 7. Using the iris data set, plot boxplot of its numeric features.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(data=df6)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 8. Import the built-in 'diamonds' data set from seaborn. For the variable 'cut', plot a count plot.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df8 = sns.load_dataset('diamonds')
sns.countplot(data=df8,x='cut')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 9. Use the iris data set, to plot a joint plot of sepal length against sepal width.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.jointplot(data=df6,x='sepal_length',y= 'sepal_width')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 10. Jake's monthly expenditure is given below. Draw a pie chart and explode the wedge with highest cost
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#     <tr>
#         <th> Item  </th>
#         <th> Expenditure </th>
#     </tr>
#     <tr>
#         <th> Food </th>
#         <th> 15</th>
#     </tr>
#     <tr>
#         <th> Clothing </th>
#         <th> 10</th>
#     </tr>
#     <tr>
#         <th> Rent </th>
#         <th> 40 </th>
#     </tr>
#     <tr>
#         <th> Education </th>
#         <th> 25</th>
#     </tr>
#     <tr>
#         <th> Unforseen Events </th>
#         <th> 5</th>
#     </tr>
#     <tr>
#         <th> Medicine </th>
#         <th>5</th>
#     </tr>
# </table>

# %%
df10 = pd.DataFrame({'Item':['Food','Clothing','Rent','Education','Unforseen Events','Medicine'],
                   'Expenditure':[15,10,40,25,5,5]})

plt.pie(data= df10,x='Expenditure',autopct='%1.1f%%',labels='Item', explode=(0,0,0.1,0,0,0))
plt.show()
